# %% [markdown]
# ## STUDENT PERFORMANCE FACTORS - COMPLETE EDA PROJECT

# %%
# If libraries are not installed, uncomment the next line:
# !pip install pandas numpy matplotlib seaborn

# %% [markdown]
# ## 1. IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting style
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# ## 2. LOAD DATASET

# %%
# Make sure StudentPerformanceFactors.csv is in the same
# folder as your Jupyter Notebook.

df = pd.read_csv("StudentPerformanceFactors.csv")

print("=" * 60)
print("DATASET LOADED SUCCESSFULLY")
print("=" * 60)

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nFirst 5 rows:")
print(df.head())

# %% [markdown]
# ## 3. BASIC DATASET INFORMATION

# %%
print("\n" + "=" * 60)
print("DATASET INFORMATION")
print("=" * 60)

print("\nData types and non-null values:")
df.info()

print("\nStatistical summary:")
print(df.describe())

print("\nCategorical variables summary:")
print(df.describe(include="object"))

# %% [markdown]
# ## 4. CHECK MISSING VALUES

# %%
print("\n" + "=" * 60)
print("MISSING VALUES")
print("=" * 60)

missing = df.isnull().sum()

missing_percent = (df.isnull().sum() / len(df)) * 100

missing_table = pd.DataFrame({
    "Missing Values": missing,
    "Percentage": missing_percent
})

print(missing_table.sort_values(
    by="Missing Values",
    ascending=False
))

# %% [markdown]
# ## 5. CHECK DUPLICATES

# %%
print("\n" + "=" * 60)
print("DUPLICATE ROWS")
print("=" * 60)

duplicates = df.duplicated().sum()

print("Number of duplicate rows:", duplicates)

# Remove duplicate rows
df = df.drop_duplicates()

print("Dataset shape after removing duplicates:", df.shape)

# %% [markdown]
# ## 6. HANDLE MISSING VALUES

# %%
print("\n" + "=" * 60)
print("HANDLING MISSING VALUES")
print("=" * 60)

# Separate categorical and numerical columns
categorical_columns = df.select_dtypes(
    include="object"
).columns

numerical_columns = df.select_dtypes(
    include=np.number
).columns

# Fill categorical missing values using mode
for column in categorical_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(
            df[column].mode()[0]
        )

# Fill numerical missing values using median
for column in numerical_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(
            df[column].median()
        )

print("Missing values after cleaning:")
print(df.isnull().sum())

# %% [markdown]
# ## 7. COLUMN INFORMATION

# %%
print("\n" + "=" * 60)
print("NUMERICAL COLUMNS")
print("=" * 60)

print(list(numerical_columns))

print("\n" + "=" * 60)
print("CATEGORICAL COLUMNS")
print("=" * 60)

print(list(categorical_columns))

# %% [markdown]
# ## 8. EXAM SCORE DISTRIBUTION

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="Exam_Score",
    bins=20,
    kde=True
)

plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. EXAM SCORE BOX PLOT

# %%
plt.figure(figsize=(10, 4))

sns.boxplot(
    data=df,
    x="Exam_Score"
)

plt.title("Box Plot of Exam Scores")
plt.xlabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. HISTOGRAMS FOR IMPORTANT NUMERICAL VARIABLES

# %%
numeric_features = [
    "Hours_Studied",
    "Attendance",
    "Sleep_Hours",
    "Previous_Scores",
    "Tutoring_Sessions",
    "Physical_Activity",
    "Exam_Score"
]

for column in numeric_features:

    plt.figure(figsize=(10, 6))

    sns.histplot(
        data=df,
        x=column,
        bins=20,
        kde=True
    )

    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Number of Students")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 11. BOX PLOT - HOURS STUDIED

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(
    data=df,
    x="Hours_Studied"
)

plt.title("Distribution of Hours Studied")
plt.xlabel("Hours Studied Per Week")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. BOX PLOT - EXAM SCORE BY MOTIVATION

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Motivation_Level",
    y="Exam_Score"
)

plt.title("Exam Scores by Motivation Level")
plt.xlabel("Motivation Level")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. BOX PLOT - EXAM SCORE BY PARENTAL INVOLVEMENT

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Parental_Involvement",
    y="Exam_Score"
)

plt.title("Exam Scores by Parental Involvement")
plt.xlabel("Parental Involvement")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14. SCATTER PLOT - STUDY HOURS VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Hours_Studied",
    y="Exam_Score",
    alpha=0.5
)

plt.title("Study Hours vs Exam Score")
plt.xlabel("Hours Studied Per Week")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 15. REGRESSION PLOT - STUDY HOURS VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=df,
    x="Hours_Studied",
    y="Exam_Score",
    scatter_kws={"alpha": 0.3}
)

plt.title("Relationship Between Study Hours and Exam Score")
plt.xlabel("Hours Studied Per Week")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16. SCATTER PLOT - ATTENDANCE VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Attendance",
    y="Exam_Score",
    alpha=0.5
)

plt.title("Attendance vs Exam Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 17. REGRESSION PLOT - ATTENDANCE VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=df,
    x="Attendance",
    y="Exam_Score",
    scatter_kws={"alpha": 0.3}
)

plt.title("Relationship Between Attendance and Exam Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 18. SCATTER PLOT - PREVIOUS SCORES VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Previous_Scores",
    y="Exam_Score",
    alpha=0.5
)

plt.title("Previous Scores vs Exam Score")
plt.xlabel("Previous Scores")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 19. AVERAGE EXAM SCORE BY MOTIVATION

# %%
motivation_average = (
    df.groupby("Motivation_Level")["Exam_Score"]
    .mean()
    .sort_values(ascending=False)
)

print("\nAverage Exam Score by Motivation Level:")
print(motivation_average)


plt.figure(figsize=(10, 6))

sns.barplot(
    data=df,
    x="Motivation_Level",
    y="Exam_Score",
    estimator="mean"
)

plt.title("Average Exam Score by Motivation Level")
plt.xlabel("Motivation Level")
plt.ylabel("Average Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 20. AVERAGE EXAM SCORE BY PARENTAL INVOLVEMENT

# %%
parental_average = (
    df.groupby("Parental_Involvement")["Exam_Score"]
    .mean()
    .sort_values(ascending=False)
)

print("\nAverage Exam Score by Parental Involvement:")
print(parental_average)


plt.figure(figsize=(10, 6))

sns.barplot(
    data=df,
    x="Parental_Involvement",
    y="Exam_Score",
    estimator="mean"
)

plt.title("Average Exam Score by Parental Involvement")
plt.xlabel("Parental Involvement")
plt.ylabel("Average Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 21. AVERAGE EXAM SCORE BY FAMILY INCOME

# %%
family_income_average = (
    df.groupby("Family_Income")["Exam_Score"]
    .mean()
    .sort_values(ascending=False)
)

print("\nAverage Exam Score by Family Income:")
print(family_income_average)


plt.figure(figsize=(10, 6))

sns.barplot(
    data=df,
    x="Family_Income",
    y="Exam_Score",
    estimator="mean"
)

plt.title("Average Exam Score by Family Income")
plt.xlabel("Family Income")
plt.ylabel("Average Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 22. SCHOOL TYPE VS EXAM SCORE

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(
    data=df,
    x="School_Type",
    y="Exam_Score"
)

plt.title("Exam Scores by School Type")
plt.xlabel("School Type")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 23. GENDER VS EXAM SCORE

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(
    data=df,
    x="Gender",
    y="Exam_Score"
)

plt.title("Exam Scores by Gender")
plt.xlabel("Gender")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 24. INTERNET ACCESS VS EXAM SCORE

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(
    data=df,
    x="Internet_Access",
    y="Exam_Score"
)

plt.title("Exam Scores by Internet Access")
plt.xlabel("Internet Access")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 25. TUTORING SESSIONS VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Tutoring_Sessions",
    y="Exam_Score"
)

plt.title("Exam Scores by Number of Tutoring Sessions")
plt.xlabel("Tutoring Sessions")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 26. SLEEP HOURS VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Sleep_Hours",
    y="Exam_Score"
)

plt.title("Exam Scores by Sleep Hours")
plt.xlabel("Sleep Hours")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 27. PEER INFLUENCE VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Peer_Influence",
    y="Exam_Score"
)

plt.title("Exam Scores by Peer Influence")
plt.xlabel("Peer Influence")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 28. ACCESS TO RESOURCES VS EXAM SCORE

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Access_to_Resources",
    y="Exam_Score"
)

plt.title("Exam Scores by Access to Resources")
plt.xlabel("Access to Resources")
plt.ylabel("Exam Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 29. CORRELATION MATRIX

# %%
correlation = df[numerical_columns].corr()

print("\n" + "=" * 60)
print("CORRELATION MATRIX")
print("=" * 60)

print(correlation)

# %% [markdown]
# ## 30. CORRELATION HEATMAP

# %%
plt.figure(figsize=(14, 10))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Variables")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 31. CORRELATION WITH EXAM SCORE

# %%
exam_correlations = (
    correlation["Exam_Score"]
    .sort_values(ascending=False)
)

print("\n" + "=" * 60)
print("CORRELATIONS WITH EXAM SCORE")
print("=" * 60)

print(exam_correlations)

# %% [markdown]
# ## 32. VISUALIZE CORRELATIONS WITH EXAM SCORE

# %%
plt.figure(figsize=(10, 7))

exam_correlations_without_target = (
    exam_correlations.drop("Exam_Score")
    .sort_values()
)

exam_correlations_without_target.plot(
    kind="barh"
)

plt.title("Correlation of Numerical Variables with Exam Score")
plt.xlabel("Correlation")
plt.ylabel("Variable")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 33. STUDY HOURS + MOTIVATION

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Hours_Studied",
    y="Exam_Score",
    hue="Motivation_Level",
    alpha=0.6
)

plt.title(
    "Study Hours and Exam Scores by Motivation Level"
)

plt.xlabel("Hours Studied Per Week")
plt.ylabel("Exam Score")
plt.legend(title="Motivation Level")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 34. SUMMARY TABLE - MOTIVATION

# %%
print("\n" + "=" * 60)
print("MOTIVATION SUMMARY")
print("=" * 60)

motivation_summary = df.groupby(
    "Motivation_Level"
)["Exam_Score"].agg(
    ["count", "mean", "median", "min", "max"]
)

print(motivation_summary)

# %% [markdown]
# ## 35. SUMMARY TABLE - PARENTAL INVOLVEMENT

# %%
print("\n" + "=" * 60)
print("PARENTAL INVOLVEMENT SUMMARY")
print("=" * 60)

parental_summary = df.groupby(
    "Parental_Involvement"
)["Exam_Score"].agg(
    ["count", "mean", "median", "min", "max"]
)

print(parental_summary)

# %% [markdown]
# ## 36. SUMMARY TABLE - FAMILY INCOME

# %%
print("\n" + "=" * 60)
print("FAMILY INCOME SUMMARY")
print("=" * 60)

income_summary = df.groupby(
    "Family_Income"
)["Exam_Score"].agg(
    ["count", "mean", "median", "min", "max"]
)

print(income_summary)

# %% [markdown]
# ## 37. FINAL DATASET SUMMARY

# %%
print("\n" + "=" * 60)
print("FINAL DATASET SUMMARY")
print("=" * 60)

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nMissing values:")
print(df.isnull().sum().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

print("\nAverage Exam Score:")
print(round(df["Exam_Score"].mean(), 2))

print("\nMedian Exam Score:")
print(df["Exam_Score"].median())

print("\nMinimum Exam Score:")
print(df["Exam_Score"].min())

print("\nMaximum Exam Score:")
print(df["Exam_Score"].max())

# %% [markdown]
# ## 38. AUTOMATICALLY PRINT POSSIBLE INSIGHTS

# %%
print("\n" + "=" * 60)
print("POSSIBLE INSIGHTS TO INVESTIGATE")
print("=" * 60)

# Strongest numerical correlation excluding Exam_Score itself
strongest_positive = (
    exam_correlations.drop("Exam_Score")
    .sort_values(ascending=False)
    .index[0]
)

strongest_negative = (
    exam_correlations.drop("Exam_Score")
    .sort_values()
    .index[0]
)

print(
    f"1. The numerical variable most positively correlated "
    f"with Exam Score is: {strongest_positive}"
)

print(
    f"2. The numerical variable most negatively correlated "
    f"with Exam Score is: {strongest_negative}"
)

# Motivation
highest_motivation = motivation_average.index[0]
lowest_motivation = motivation_average.index[-1]

print(
    f"3. The motivation group with the highest average "
    f"exam score is: {highest_motivation}"
)

print(
    f"4. The motivation group with the lowest average "
    f"exam score is: {lowest_motivation}"
)

# Parental involvement
highest_parental = parental_average.index[0]
lowest_parental = parental_average.index[-1]

print(
    f"5. The parental involvement group with the highest "
    f"average exam score is: {highest_parental}"
)

# %% [markdown]
# ## 39. FINAL MESSAGE

# %%
print("\n" + "=" * 60)
print("EDA COMPLETE!")
print("=" * 60)

print("""
You have completed:

- Data loading
- Dataset inspection
- Missing-value analysis
- Duplicate analysis
- Data cleaning
- Descriptive statistics
- Histograms
- Box plots
- Scatter plots
- Regression plots
- Bar charts
- Correlation analysis
- Correlation heatmap
- Categorical analysis
- 3-5 possible insights

Next step:
Review the charts and write 3-5 insights in plain language.
Do not claim that one variable causes another unless you have
evidence for causation.
""")
