# %%
file = open("student.txt", "w")

file.write("Name: Kyatrina\n")
file.write("Age: 19\n")
file.write("Course: Data Science")

file.close()

print("Data written successfully!")
# Out:
# Data written successfully!

# %%
file = open("student.txt", "r")

content = file.read()

print(content)

file.close()
# Out:
# Name: Kyatrina
# Age: 19
# Course: Data Science

# %%
file = open("student.txt", "a")

file.write("\nCollege: Itahari International College")

file.close()

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %%
file = open("student.txt", "r")

text = file.read()

words = text.split()

print("Total Words:", len(words))

file.close()
# Out:
# Total Words: 14

# %%
class Student:
    def display(self):
        print("Welcome to Data Science Internship")

student = Student()
student.display()
# Out:
# Welcome to Data Science Internship

# %%
class Student:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)

student1 = Student("Kyatrina", 19)

student1.display()
# Out:
# Name: Kyatrina
# Age: 19

# %%
class Employee:

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display(self):
        print(self.name, "-", self.salary)

emp1 = Employee("Kyatrina", 40000)
emp2 = Employee("Shrestha", 55000)

emp1.display()
emp2.display()
# Out:
# Kyatrina - 40000
# Shrestha - 55000

# %%
class Student:

    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("\nStudent Details")
        print("---------------")
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)


name = input("Enter Name: ")
age = input("Enter Age: ")
course = input("Enter Course: ")

student = Student(name, age, course)

student.display()

file = open("records.txt", "a")
file.write(f"{name}, {age}, {course}\n")
file.close()

print("\nRecord saved successfully!")
# Out:
# Enter Name:  Kyatrina
# Enter Age:  19
# Enter Course:  Data Science
# Student Details
# ---------------
# Name: Kyatrina
# Age: 19
# Course: Data Science
#
# Record saved successfully!

# %%
file = open("records.txt", "r")

for line in file:
    print(line.strip())

file.close()
# Out:
# Kyatrina, 19, Data Science
