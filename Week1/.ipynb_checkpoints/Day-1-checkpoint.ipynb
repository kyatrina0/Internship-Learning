# %%
print("Hello, Data Science Internship!")
print("My name is Kyatrina")
print("Day 1 Completed")
# Out:
# Hello, Data Science Internship!
# My name is Kyatrina
# Day 1 Completed

# %%
name = "Kyatrina"
age = 19
height = 5.2
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Kyatrina
# 19
# 5.2
# True

# %%
city = "Dharan"
country = "Nepal"
temperature = 32

print("City:", city)
print("Country:", country)
print("Temperature:", temperature)
# Out:
# City: Dharan
# Country: Nepal
# Temperature: 32

# %%
name = input("Enter your name: ")

print("Welcome", name)
# Out:
# Enter your name:  Kyatrina
# Welcome Kyatrina

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello", name)
print("You are", age, "years old.")
# Out:
# Enter your name:  Kyatrina
# Enter your age:  19
# Hello Kyatrina
# You are 19 years old.
