# %%
CREATE TABLE employees (
    id INT,
    name VARCHAR(30),
    department VARCHAR(20),
    salary INT
);

INSERT INTO employees VALUES
(1,'Kyatrina','HR',40000),
(2,'Susmita','IT',60000),
(3,'Arav','IT',55000),
(4,'Badal','Finance',50000),
(5,'Bibek','HR',45000);
# Out:
#   Cell In[1], line 1
#     CREATE TABLE employees (
#            ^
# SyntaxError: invalid syntax
